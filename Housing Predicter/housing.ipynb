# %% [markdown]
# # KernelEstimate: Predicting Home Sale Prices

# %% [markdown]
# ---
# embed-resources: true
# echo: false
# ---

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this report, I develop a model estimates the sale price of homes based on key property features such as Lot Frontage, Sale Type, and various structural and neighborhood characteristics. This model aims to create an accurate KernelEstimate model for CornHawkHomes that minimizes prediction errors and provides users with reliable guidance when evaluating homes specifically in the Ames, Iowa market. Using residential sales data from 2006–2010, I preprocess both numerical and categorical variables and train a tuned Random Forest regression model within a complete machine learning pipeline. I evaluate the model using Mean Absolute Percentage Error (MAPE) and the proportion of predictions within 20% of the true sale price, ensuring the final model meets the performance standards required for production deployment.

# %% [markdown]
# ## Methods

# %%
# imports
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
import numpy as np

# %% [markdown]
# ### Data

# %%
# load data

# %%
# summary statistics

# %%
# exploratory visualization

# %% [markdown]
# ### Models

# %%
# process data for ML

# %%
# train models

# %% [markdown]
# ## Results

# %%
# report model metrics

# %%
# summary figure

# %%
# serialize model

# %% [markdown]
# ## Discussion
